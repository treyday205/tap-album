# %% [markdown]
# <a href="https://colab.research.google.com/github/treyday205/tap-album/blob/main/MusicGen_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b v1.0 https://github.com/camenduru/audiocraft
# %cd /content/audiocraft
# !pip install -r requirements.txt
# !python app.py --share
# Out:
# /content
# fatal: destination path 'audiocraft' already exists and is not an empty directory.
# /content/audiocraft
# ...
#   Using cached av-16.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# ...
#   Using cached flashy-0.0.2.tar.gz (72 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# ...
#   Using cached julius-0.2.7.tar.gz (59 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached spacy-3.5.2.tar.gz (1.2 MB)
